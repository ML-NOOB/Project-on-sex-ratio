# %%
#IMPORTING NECESSARY LIBRARIES
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import scipy
from scipy import stats
import random

# %%
df = pd.read_excel('C:/Users/shubh/Desktop/project.xlsx','Sheet2')
df
# Out:
#      State                    District Rural /urban classification  \
# 0   PUNJAB                    Amritsar                        both
# 1   PUNJAB                     Barnala                        both
# 2   PUNJAB                    Bathinda                        both
# 3   PUNJAB                    Faridkot                        both
# 4   PUNJAB            Fatehgarh Sahib,                        both
# 5   PUNJAB                    Firozpur                       rural
# 6   PUNJAB                   Gurdaspur                       rural
# 7   PUNJAB                  Hoshiarpur                       rural
# 8   PUNJAB                   Jalandhar                        both
# 9   PUNJAB                  Kapurthala                        both
# 10  PUNJAB                    Ludhiana                        both
# 11  PUNJAB                       Mansa                       rural
# 12  PUNJAB                        Moga                       rural
# 13  PUNJAB                     Muktsar                       rural
# 14  PUNJAB                     Patiala                        both
# 15  PUNJAB                   Rup Nagar                       rural
# 16  PUNJAB  Sahibzada Ajit Singh Nagar                        both
# 17  PUNJAB                     Sangrur                       rural
# 18  PUNJAB    Sahid Bhagat Singh Nagar                       rural
# 19  PUNJAB                 Taran taran                       rural
#
#     Sex ratio of the total population (females per 1,000 males)  \
# 0                                                 916
# 1                                                 873
# 2                                                 914
# 3                                                 888
# 4                                                 927
# 5                                                 907
# 6                                                 898
# 7                                                 943
# 8                                                 953
# 9                                                 958
# 10                                                862
# 11                                                908
# 12                                                897
# 13                                                860
# 14                                                903
# 15                                                950
# 16                                                864
# 17                                                893
# 18                                               1011
# 19                                                914
#
#     Sex ratio at birth for children born in the last five years  \
# 0                                                 772
# 1                                                1026
# 2                                                 991
# 3                                                 968
# 4                                                 872
# 5                                                1014
# 6                                                 829
# 7                                                 894
# 8                                                 711
# 9                                                 776
# 10                                                827
# 11                                                884
# 12                                               1057
# 13                                                748
# 14                                                909
# 15                                                827
# 16                                                815
# 17                                                736
# 18                                               1154
# 19                                                962
#
#     Women who are literate (%)  Men who are literate (%)  \
# 0                         78.5                      85.0
# 1                         77.1                      80.6
# 2                         76.2                      88.6
# 3                         76.9                      83.9
# 4                         88.4                      95.2
# 5                         67.7                      82.4
# 6                         88.2                      90.4
# 7                         90.4                      81.7
# 8                         89.1                      90.5
# 9                         87.1                      87.3
# 10                        85.0                      87.2
# 11                        68.4                      87.0
# 12                        77.9                      85.6
# 13                        77.4                      89.0
# 14                        83.6                      94.2
# 15                        88.6                      96.1
# 16                        84.3                      91.0
# 17                        74.3                      86.0
# 18                        86.7                      96.3
# 19                        75.5                      76.3
#
#     Women with 10 or more years of schooling (%)  \
# 0                                           53.1
# 1                                           46.0
# 2                                           50.8
# 3                                           50.3
# 4                                           58.5
# 5                                           34.5
# 6                                           62.7
# 7                                           64.3
# 8                                           68.6
# 9                                           59.8
# 10                                          62.5
# 11                                          38.2
# 12                                          47.1
# 13                                          47.6
# 14                                          57.8
# 15                                          61.2
# 16                                          59.5
# 17                                          47.8
# 18                                          58.4
# 19                                          46.0
#
#     Households with an improved drinking-water source1 (%)  \
# 0                                               100.0
# 1                                                98.9
# 2                                                96.7
# 3                                                97.3
# 4                                                99.5
# 5                                                99.7
# 6                                                99.6
# 7                                                99.8
# 8                                                99.8
# 9                                                98.8
# 10                                              100.0
# 11                                               98.4
# 12                                               99.1
# 13                                               98.7
# 14                                               99.4
# 15                                               99.8
# 16                                               99.4
# 17                                               98.6
# 18                                               99.9
# 19                                              100.0
#
#     Households using improved sanitation facility2 (%)  \
# 0                                                78.3
# 1                                                85.5
# 2                                                85.0
# 3                                                83.7
# 4                                                83.0
# 5                                                96.8
# 6                                                74.7
# 7                                                76.2
# 8                                                89.2
# 9                                                81.8
# 10                                               80.8
# 11                                               75.0
# 12                                               86.9
# 13                                               79.6
# 14                                               87.5
# 15                                               80.9
# 16                                               79.4
# 17                                               87.7
# 18                                               81.6
# 19                                               77.9
#
#     Households using clean fuel for cooking3  Quality of life indicator  \
# 0                                       72.8                   0.655296
# 1                                       54.4                   0.499831
# 2                                       62.7                   0.339062
# 3                                       64.2                   0.392529
# 4                                       69.4                   0.647418
# 5                                       77.1                   0.939772
# 6                                       69.8                   0.535656
# 7                                       62.7                   0.519463
# 8                                       78.7                   0.848542
# 9                                       76.1                   0.614306
# 10                                      76.8                   0.726254
# 11                                      40.6                   0.176242
# 12                                      55.4                   0.549462
# 13                                      59.3                   0.431371
# 14                                      68.6                   0.698541
# 15                                      67.6                   0.631085
# 16                                      80.7                   0.676951
# 17                                      51.8                   0.481098
# 18                                      55.1                   0.547837
# 19                                      55.1                   0.502131
#
#     Institutional births (%)
# 0                       90.0
# 1                       96.3
# 2                       94.7
# 3                       95.5
# 4                       94.3
# 5                       86.0
# 6                       87.3
# 7                       91.3
# 8                       95.7
# 9                       91.2
# 10                      82.5
# 11                      91.3
# 12                      93.1
# 13                      93.6
# 14                      96.9
# 15                      91.3
# 16                      88.9
# 17                      88.0
# 18                      91.8
# 19                      90.5

# %%
#MIN_MAX scaling. the reason for choosing min_max scaling to bring about relative differences between districts
#and also allow us to compare data points by sclaing them in the interval(0,1)

df['sex ratio scaled'] = (df['Sex ratio of the total population (females per 1,000 males)'] - min(df['Sex ratio of the total population (females per 1,000 males)']))/(max(df['Sex ratio of the total population (females per 1,000 males)'])-min(df['Sex ratio of the total population (females per 1,000 males)']))
df['Child sex ratio scaled'] = (df['Sex ratio at birth for children born in the last five years'] - min(df['Sex ratio at birth for children born in the last five years']))/(max(df['Sex ratio at birth for children born in the last five years'])-min(df['Sex ratio at birth for children born in the last five years']))
df['Mens Literacy rate scaled'] = ((df['Men who are literate (%)'] - min(df['Men who are literate (%)']))/(max(df['Men who are literate (%)'])-min(df['Men who are literate (%)'])))
df['Womens Literacy rate scaled'] = (df['Women who are literate (%)'] - min(df['Women who are literate (%)']))/(max(df['Women who are literate (%)'])-min(df['Women who are literate (%)']))
df['Women with > 10 years of schooling scaled'] = (df['Women with 10 or more years of schooling (%)'] - min(df['Women with 10 or more years of schooling (%)']))/(max(df['Women with 10 or more years of schooling (%)'])-min(df['Women with 10 or more years of schooling (%)']))
df['Institutional births'] = (df['Institutional births (%)'] - min(df['Institutional births (%)']))/(max(df['Institutional births (%)'])-min(df['Institutional births (%)']))

# %%
# Rural urban classification is a categorical variable whuch needs to be accounted for. hence categorical variable encoding
# also encoding by 0.5 instead of one because since all data points have beeen scaled in the interval 0,1(uniform) distribution
# its suitable to encide categorical variables by 0.5. Value of 1 may lead to categorical variable playing a dominant role in 
# classification algorithm(k-means)

df.loc[df['Rural /urban classification'] == 'rural', 'ruc1'] = .5
df.loc[df['Rural /urban classification'] != 'rural', 'ruc1'] = 0
df.loc[df['Rural /urban classification'] == 'urban', 'ruc2'] = .5
df.loc[df['Rural /urban classification'] != 'urban', 'ruc2'] = 0
#df.loc[df['Rural /urban classification'] == 'both', 'ruc3'] = 1 # dummy variable trap.if its both then it automatically becomes 0
#df.loc[df['Rural /urban classification'] != 'both', 'ruc3'] = 0
Scale_df = df[['District','ruc1','ruc2','sex ratio scaled','Child sex ratio scaled','Mens Literacy rate scaled','Womens Literacy rate scaled',
            'Women with > 10 years of schooling scaled','Quality of life indicator','Institutional births']]

# %%
#extrapolatory data analysis
#SInce we are intrested in Sex ratio and child sex ratio, our foccus would be relationship of these variables 
#with other variables
Scale_df.corr()
# Out:
#                                                ruc1  ruc2  sex ratio scaled  \
# ruc1                                       1.000000   NaN          0.168128
# ruc2                                            NaN   NaN               NaN
# sex ratio scaled                           0.168128   NaN          1.000000
# Child sex ratio scaled                     0.187190   NaN          0.214411
# Mens Literacy rate scaled                 -0.121541   NaN          0.346817
# Womens Literacy rate scaled               -0.229739   NaN          0.420751
# Women with > 10 years of schooling scaled -0.336186   NaN          0.343012
# Quality of life indicator                 -0.233033   NaN          0.123657
# Institutional births                      -0.300961   NaN          0.180446
#
#                                            Child sex ratio scaled  \
# ruc1                                                     0.187190
# ruc2                                                          NaN
# sex ratio scaled                                         0.214411
# Child sex ratio scaled                                   1.000000
# Mens Literacy rate scaled                               -0.141514
# Womens Literacy rate scaled                             -0.258038
# Women with > 10 years of schooling scaled               -0.379338
# Quality of life indicator                               -0.159976
# Institutional births                                     0.196390
#
#                                            Mens Literacy rate scaled  \
# ruc1                                                       -0.121541
# ruc2                                                             NaN
# sex ratio scaled                                            0.346817
# Child sex ratio scaled                                     -0.141514
# Mens Literacy rate scaled                                   1.000000
# Womens Literacy rate scaled                                 0.534940
# Women with > 10 years of schooling scaled                   0.504899
# Quality of life indicator                                   0.160537
# Institutional births                                        0.154098
#
#                                            Womens Literacy rate scaled  \
# ruc1                                                         -0.229739
# ruc2                                                               NaN
# sex ratio scaled                                              0.420751
# Child sex ratio scaled                                       -0.258038
# Mens Literacy rate scaled                                     0.534940
# Womens Literacy rate scaled                                   1.000000
# Women with > 10 years of schooling scaled                     0.958881
# Quality of life indicator                                     0.329006
# Institutional births                                          0.073014
#
#                                            Women with > 10 years of schooling scaled  \
# ruc1                                                                       -0.336186
# ruc2                                                                             NaN
# sex ratio scaled                                                            0.343012
# Child sex ratio scaled                                                     -0.379338
# Mens Literacy rate scaled                                                   0.504899
# Womens Literacy rate scaled                                                 0.958881
# Women with > 10 years of schooling scaled                                   1.000000
# Quality of life indicator                                                   0.324970
# Institutional births                                                        0.026344
#
#                                            Quality of life indicator  \
# ruc1                                                       -0.233033
# ruc2                                                             NaN
# sex ratio scaled                                            0.123657
# Child sex ratio scaled                                     -0.159976
# Mens Literacy rate scaled                                   0.160537
# Womens Literacy rate scaled                                 0.329006
# Women with > 10 years of schooling scaled                   0.324970
# Quality of life indicator                                   1.000000
# Institutional births                                       -0.270219
#
#                                            Institutional births
# ruc1                                                  -0.300961
# ruc2                                                        NaN
# sex ratio scaled                                       0.180446
# Child sex ratio scaled                                 0.196390
# Mens Literacy rate scaled                              0.154098
# Womens Literacy rate scaled                            0.073014
# Women with > 10 years of schooling scaled              0.026344
# Quality of life indicator                             -0.270219
# Institutional births                                   1.000000

# %%
corr =Scale_df.corr()
corr.to_excel("correlation matrix Punjab.xlsx")

# %%
def regressions(pd1 , pd2, x,y):
    data1 = pd.DataFrame(pd1)
    data2 = pd.DataFrame(pd2)
    plt.scatter(data1,data2, c ='Red')
    cov = (((data1*data2).mean())-(data1.mean()*data2.mean())).mean()
    slope = cov/data1.var()
    lm = (data1)* slope
    z= (data2 - lm).mean()
    lm = lm+z
    plt.scatter(data1 ,lm)
    plt.xlabel(x)
    plt.ylabel(y)
    plt.title('PUNJAB')
    R2 = ((lm - data2)**2).sum()/(((data2-data2.mean())**2).sum())
    R2 = 1- R2
    print(" Slope is ", slope)
    print("The R^2 value for the above regression is",R2)
    #file_name = (str('%.2f'%slope[0])+'.png')
    #plt.savefig(file_name)
    bootstrap(data1,data2,slope)

# %%
def bootstrap(x,y,slope):
   X = pd.DataFrame(x)
   Y = pd.DataFrame(y)
   Z = pd.merge(X, Y, left_index=True, right_index=True)
   Z.rename(columns = {'0_x': 'X'}, inplace = True)
   Z.rename(columns = {'0_y': 'Y'}, inplace = True)
   s= []
   for j in range(0,300):
         BS = Z[['X','Y']].sample(frac = 1.5, replace = True)
         slope1 = (BS.cov().loc['X','Y'])/(BS['X'].var())
         s.append(slope1)
   #s= pd.DataFrame(s)
   t_value,p_value=stats.ttest_1samp(s,slope)
   print("The P_value of slope is ",p_value)
   if (p_value > 0.05):
        print("NOT STATISICALLY SIGNIFICANT")
   else :
    print("STATISICALLY SIGNIFICANT")

# %%
regressions(Scale_df['Mens Literacy rate scaled'].values, Scale_df['sex ratio scaled'].values,'Mens Literacy rate scaled','sex ratio scaled')
# Out:
#  Slope is  0    0.305535
# dtype: float64
# The R^2 value for the above regression is 0    0.119981
# dtype: float64
# The P_value of slope is  [0.00182242]
# STATISICALLY SIGNIFICANT

# %%
regressions(Scale_df['Womens Literacy rate scaled'].values, Scale_df['sex ratio scaled'].values,'Womens Literacy rate scaled','sex ratio scaled')
# Out:
#  Slope is  0    0.324741
# dtype: float64
# The R^2 value for the above regression is 0    0.176589
# dtype: float64
# The P_value of slope is  [4.07671451e-05]
# STATISICALLY SIGNIFICANT

# %%
regressions(Scale_df['Women with > 10 years of schooling scaled'].values, Scale_df['sex ratio scaled'].values,'Women with > 10 years of schooling scaled','sex ratio scaled')
# Out:
#  Slope is  0    0.306244
# dtype: float64
# The R^2 value for the above regression is 0    0.117363
# dtype: float64
# The P_value of slope is  [5.55164943e-05]
# STATISICALLY SIGNIFICANT

# %%
regressions(Scale_df['Quality of life indicator'].values, Scale_df['sex ratio scaled'].values,'Quality of life indicator','sex ratio scaled')
# Out:
#  Slope is  0    0.169042
# dtype: float64
# The R^2 value for the above regression is 0    0.015253
# dtype: float64
# The P_value of slope is  [0.55262006]
# NOT STATISICALLY SIGNIFICANT

# %%
regressions(Scale_df['Mens Literacy rate scaled'].values, Scale_df['Child sex ratio scaled'].values,'Mens Literacy rate scaled','Child sex ratio scaled')
# Out:
#  Slope is  0   -0.135912
# dtype: float64
# The R^2 value for the above regression is 0    0.019976
# dtype: float64
# The P_value of slope is  [0.0207211]
# STATISICALLY SIGNIFICANT

# %%
regressions(Scale_df['Womens Literacy rate scaled'].values, Scale_df['Child sex ratio scaled'].values,'Womens Literacy rate scaled','Child sex ratio scaled')
# Out:
#  Slope is  0   -0.217118
# dtype: float64
# The R^2 value for the above regression is 0    0.066417
# dtype: float64
# The P_value of slope is  [0.04291882]
# STATISICALLY SIGNIFICANT

# %%
regressions(Scale_df['Quality of life indicator'].values, Scale_df['Child sex ratio scaled'].values,'Quality of life indicator','Child sex ratio scaled')
# Out:
#  Slope is  0   -0.238412
# dtype: float64
# The R^2 value for the above regression is 0    0.025528
# dtype: float64
# The P_value of slope is  [2.92e-07]
# STATISICALLY SIGNIFICANT

# %%
regressions(Scale_df['Women with > 10 years of schooling scaled'].values, Scale_df['Child sex ratio scaled'].values,'Women with > 10 years of schooling scaled','Child sex ratio scaled')
# Out:
#  Slope is  0   -0.369219
# dtype: float64
# The R^2 value for the above regression is 0    0.143538
# dtype: float64
# The P_value of slope is  [0.08711975]
# NOT STATISICALLY SIGNIFICANT

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# %%
x= Scale_df.loc[:,['Womens Literacy rate scaled','Mens Literacy rate scaled',]]#'Institutional births','Quality of life indicator']]
y= Scale_df.loc[:,['sex ratio scaled']]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.2, random_state = 1)

# %%
regressor1 = LinearRegression()
regressor1.fit(x_train,y_train) # fitting regression line
# Out:
# LinearRegression()

# %%
z=(max(df['Sex ratio of the total population (females per 1,000 males)'])-min(df['Sex ratio of the total population (females per 1,000 males)']))
a = min(df['Sex ratio of the total population (females per 1,000 males)'])

y_pred = regressor1.predict(x_test) #predicting using linear regression
regressor1.coef_
r2_score(y_test,y_pred)
# Out:
# -11.97710948537932

# %%
np.set_printoptions(precision = 2)
print(np.concatenate(((y_pred),(y_test)),1))
# Out:
# [[0.31 0.19]
#  [0.49 0.03]
#  [0.56 0.25]
#  [0.48 0.01]]

# %%
x = ((((y_pred - y_test)*(z))**2).mean())**0.5
print("The root mean square error is",x)
# Out:
# The root mean square error is sex ratio scaled    55.574743
# dtype: float64

# %%
#Using clusterin alogorith to find group together data points and find any underlying pattern in it

# %%
df_clustering = Scale_df[['ruc1','ruc2','sex ratio scaled','Child sex ratio scaled','Mens Literacy rate scaled','Womens Literacy rate scaled',
            'Women with > 10 years of schooling scaled','Quality of life indicator','Institutional births']].values
from sklearn.cluster import KMeans
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(df_clustering)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11),wcss)
plt.title('The elbow method')
plt.xlabel('No of clusters')
plt.ylabel('wcss')
#the rarte of change of wcss decreases after 5 clusters , so we choose 5 as k in K means
# Out:
# Text(0, 0.5, 'wcss')

# %%
kmeans2 = KMeans(n_clusters = 5, init = 'k-means++', random_state = 42)
kmeans1 = KMeans(n_clusters = 1, init = 'k-means++', random_state = 43)
y_kmeans = kmeans2.fit_predict(df_clustering)
wcss2 = kmeans2.inertia_
y_kmeans
# Out:
# array([4, 3, 3, 3, 0, 1, 4, 0, 0, 0, 4, 1, 3, 1, 0, 0, 4, 1, 2, 3])

# %%
ser1 = DataFrame(y_kmeans)
ser1
Scale_df = pd.merge(Scale_df, ser1, left_index=True, right_index=True)
Scale_df
# Out:
#                       District  ruc1  ruc2  sex ratio scaled  \
# 0                     Amritsar   0.0   0.0          0.370861
# 1                      Barnala   0.0   0.0          0.086093
# 2                     Bathinda   0.0   0.0          0.357616
# 3                     Faridkot   0.0   0.0          0.185430
# 4             Fatehgarh Sahib,   0.0   0.0          0.443709
# 5                     Firozpur   0.5   0.0          0.311258
# 6                    Gurdaspur   0.5   0.0          0.251656
# 7                   Hoshiarpur   0.5   0.0          0.549669
# 8                    Jalandhar   0.0   0.0          0.615894
# 9                   Kapurthala   0.0   0.0          0.649007
# 10                    Ludhiana   0.0   0.0          0.013245
# 11                       Mansa   0.5   0.0          0.317881
# 12                        Moga   0.5   0.0          0.245033
# 13                     Muktsar   0.5   0.0          0.000000
# 14                     Patiala   0.0   0.0          0.284768
# 15                   Rup Nagar   0.5   0.0          0.596026
# 16  Sahibzada Ajit Singh Nagar   0.0   0.0          0.026490
# 17                     Sangrur   0.5   0.0          0.218543
# 18    Sahid Bhagat Singh Nagar   0.5   0.0          1.000000
# 19                 Taran taran   0.5   0.0          0.357616
#
#     Child sex ratio scaled  Mens Literacy rate scaled  \
# 0                 0.137698                      0.435
# 1                 0.711061                      0.215
# 2                 0.632054                      0.615
# 3                 0.580135                      0.380
# 4                 0.363431                      0.945
# 5                 0.683973                      0.305
# 6                 0.266366                      0.705
# 7                 0.413093                      0.270
# 8                 0.000000                      0.710
# 9                 0.146727                      0.550
# 10                0.261851                      0.545
# 11                0.390519                      0.535
# 12                0.781038                      0.465
# 13                0.083521                      0.635
# 14                0.446953                      0.895
# 15                0.261851                      0.990
# 16                0.234763                      0.735
# 17                0.056433                      0.485
# 18                1.000000                      1.000
# 19                0.566591                      0.000
#
#     Womens Literacy rate scaled  Women with > 10 years of schooling scaled  \
# 0                      0.475771                                   0.545455
# 1                      0.414097                                   0.337243
# 2                      0.374449                                   0.478006
# 3                      0.405286                                   0.463343
# 4                      0.911894                                   0.703812
# 5                      0.000000                                   0.000000
# 6                      0.903084                                   0.826979
# 7                      1.000000                                   0.873900
# 8                      0.942731                                   1.000000
# 9                      0.854626                                   0.741935
# 10                     0.762115                                   0.821114
# 11                     0.030837                                   0.108504
# 12                     0.449339                                   0.369501
# 13                     0.427313                                   0.384164
# 14                     0.700441                                   0.683284
# 15                     0.920705                                   0.782991
# 16                     0.731278                                   0.733138
# 17                     0.290749                                   0.390029
# 18                     0.837004                                   0.700880
# 19                     0.343612                                   0.337243
#
#     Quality of life indicator  Institutional births  0
# 0                    0.655296              0.520833  4
# 1                    0.499831              0.958333  3
# 2                    0.339062              0.847222  3
# 3                    0.392529              0.902778  3
# 4                    0.647418              0.819444  0
# 5                    0.939772              0.243056  1
# 6                    0.535656              0.333333  4
# 7                    0.519463              0.611111  0
# 8                    0.848542              0.916667  0
# 9                    0.614306              0.604167  0
# 10                   0.726254              0.000000  4
# 11                   0.176242              0.611111  1
# 12                   0.549462              0.736111  3
# 13                   0.431371              0.770833  1
# 14                   0.698541              1.000000  0
# 15                   0.631085              0.611111  0
# 16                   0.676951              0.444444  4
# 17                   0.481098              0.381944  1
# 18                   0.547837              0.645833  2
# 19                   0.502131              0.555556  3

# %%
Scale_df.rename(columns = {0: "Cluster Group"}, inplace = True)
df2 = Scale_df. groupby("Cluster Group")["sex ratio scaled","Quality of life indicator","Child sex ratio scaled","Mens Literacy rate scaled","Women with > 10 years of schooling scaled",'Quality of life indicator'].mean()
df3 =  df2.sort_values(by='Child sex ratio scaled')
c = df3.index
districs_of_concern = (Scale_df.loc[(Scale_df['Cluster Group'] ==c[0])]).sort_values(by='Cluster Group')
a= districs_of_concern.index 
df2
# Out:
# <ipython-input-47-938f58f5c079>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df2 = Scale_df. groupby("Cluster Group")["sex ratio scaled","Quality of life indicator","Child sex ratio scaled","Mens Literacy rate scaled","Women with > 10 years of schooling scaled",'Quality of life indicator'].mean()
#                sex ratio scaled  Quality of life indicator  \
# Cluster Group
# 0                      0.523179                   0.659892
# 1                      0.211921                   0.507121
# 2                      1.000000                   0.547837
# 3                      0.246358                   0.456603
# 4                      0.165563                   0.648539
#
#                Child sex ratio scaled  Mens Literacy rate scaled  \
# Cluster Group
# 0                            0.272009                   0.726667
# 1                            0.303612                   0.490000
# 2                            1.000000                   1.000000
# 3                            0.654176                   0.335000
# 4                            0.225169                   0.605000
#
#                Women with > 10 years of schooling scaled  \
# Cluster Group
# 0                                               0.797654
# 1                                               0.220674
# 2                                               0.700880
# 3                                               0.397067
# 4                                               0.731672
#
#                Quality of life indicator
# Cluster Group
# 0                               0.659892
# 1                               0.507121
# 2                               0.547837
# 3                               0.456603
# 4                               0.648539

# %%
print("districts of concern")
districs_of_concern
#
# Out:
# districts of concern
#                       District  ruc1  ruc2  sex ratio scaled  \
# 0                     Amritsar   0.0   0.0          0.370861
# 6                    Gurdaspur   0.5   0.0          0.251656
# 10                    Ludhiana   0.0   0.0          0.013245
# 16  Sahibzada Ajit Singh Nagar   0.0   0.0          0.026490
#
#     Child sex ratio scaled  Mens Literacy rate scaled  \
# 0                 0.137698                      0.435
# 6                 0.266366                      0.705
# 10                0.261851                      0.545
# 16                0.234763                      0.735
#
#     Womens Literacy rate scaled  Women with > 10 years of schooling scaled  \
# 0                      0.475771                                   0.545455
# 6                      0.903084                                   0.826979
# 10                     0.762115                                   0.821114
# 16                     0.731278                                   0.733138
#
#     Quality of life indicator  Institutional births  Cluster Group
# 0                    0.655296              0.520833              4
# 6                    0.535656              0.333333              4
# 10                   0.726254              0.000000              4
# 16                   0.676951              0.444444              4

# %%
df.iloc[a,[0,1,2,3,4,5,6,7,11]]
# Out:
#      State                    District Rural /urban classification  \
# 0   PUNJAB                    Amritsar                        both
# 6   PUNJAB                   Gurdaspur                       rural
# 10  PUNJAB                    Ludhiana                        both
# 16  PUNJAB  Sahibzada Ajit Singh Nagar                        both
#
#     Sex ratio of the total population (females per 1,000 males)  \
# 0                                                 916
# 6                                                 898
# 10                                                862
# 16                                                864
#
#     Sex ratio at birth for children born in the last five years  \
# 0                                                 772
# 6                                                 829
# 10                                                827
# 16                                                815
#
#     Women who are literate (%)  Men who are literate (%)  \
# 0                         78.5                      85.0
# 6                         88.2                      90.4
# 10                        85.0                      87.2
# 16                        84.3                      91.0
#
#     Women with 10 or more years of schooling (%)  Quality of life indicator
# 0                                           53.1                   0.655296
# 6                                           62.7                   0.535656
# 10                                          62.5                   0.726254
# 16                                          59.5                   0.676951
